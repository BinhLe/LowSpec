# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_res = pd.read_csv('reprice_Results_01.txt',low_memory=False)
print((df_res.shape))
df_res['RF-Gr'] = df_res['RandomForest'] - df_res['NextPrice']
df_res['XGB-Gr'] = df_res['XGBoost'] - df_res['NextPrice']

var1 = df_res['RF-Gr'].describe().reset_index()
var1.columns = ['', 'RF-Gr']
var1.reset_index(drop = True, inplace = True)

var2 = df_res['XGB-Gr'].describe().reset_index()
var2.columns = ['', 'XGB-Gr']
var2.reset_index(drop = True, inplace = True)

sns.set_style("whitegrid")
fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)
ax1.set_title("The Violinplot of Differences from RF's Recommended Prices to Groundtruth (Gr) in 25,131 Repricing Events") 
sns.violinplot(x=df_res['RF-Gr'],  color='lightblue',ax=ax1,orient='h')
plt.figtext(0.95, 0.55, var1,fontsize=14)

ax2.set_title("The Violinplot of Differences from XGB's Recommended Prices to Groundtruth (Gr) in 25,131 Repricing Events") 
sns.violinplot(x=df_res['XGB-Gr'], color='orange',ax=ax2,orient='h')
plt.figtext(0.95, 0.15, var2,fontsize=14)
for i,artist in enumerate(ax2.artists):
    # Set the linecolor on the artist to the facecolor, and set the facecolor to None
    col = artist.get_facecolor()
    artist.set_edgecolor(col)
    artist.set_facecolor('None')

    # Each box has 6 associated Line2D objects (to make the whiskers, fliers, etc.)
    # Loop over them here, and use the same colour as above
    for j in range(i*6,i*6+6):
        line = ax2.lines[j]
        line.set_color(col)
        line.set_mfc(col)
        line.set_mec(col)


plt.show()
# Out:
# (25131, 7)

# %%
df_res = pd.read_csv('reprice_Results_01.txt',low_memory=False)
print((df_res.shape))
df_res['RF-Gr'] = df_res['RandomForest'] - df_res['NextPrice']
df_res['XGB-Gr'] = df_res['XGBoost'] - df_res['NextPrice']


des1 = df_res['RF-Gr'].describe().reset_index()
des1.columns = ['', 'RF-Gr']
des1.reset_index(drop = True, inplace = True)

des2 = df_res['XGB-Gr'].describe().reset_index()
des2.columns = ['', 'XGB-Gr']
des2.reset_index(drop = True, inplace = True)

sns.set_style("whitegrid")
fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)
ax1.set_title("The Boxplot of Differences from RF's Recommended Prices to Groundtruth (Gr) in 25,131 Repricing Events") 
sns.boxplot(x=df_res['RF-Gr'],  color='lightblue',ax=ax1,orient='h')
plt.figtext(0.95, 0.55, des1,fontsize=14)

ax2.set_title("The Boxplot of Differences from XGB's Recommended Price to Groundtruth (Gr) in 25,131 Repricing Events") 
sns.boxplot(x=df_res['XGB-Gr'], color='orange',ax=ax2,orient='h')
plt.figtext(0.95, 0.15, des2,fontsize=14)



for i,artist in enumerate(ax2.artists):
    # Set the linecolor on the artist to the facecolor, and set the facecolor to None
    col = artist.get_facecolor()
    artist.set_edgecolor(col)
    artist.set_facecolor('None')

    # Each box has 6 associated Line2D objects (to make the whiskers, fliers, etc.)
    # Loop over them here, and use the same colour as above
    for j in range(i*6,i*6+6):
        line = ax2.lines[j]
        line.set_color(col)
        line.set_mfc(col)
        line.set_mec(col)


plt.show()
var1 = df_res['RF-Gr']
var2 = df_res['XGB-Gr']

fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)

ax1.set_title("The Histogram of Differences from RF's Recommended Prices to Groundtruth (Gr) in 25,131 Repricing Events") 
sns.distplot(var1,ax=ax1,color='blue')
plt.figtext(1.0, 0.55, des1,fontsize=14)

ax2.set_title("The Histogram of Differences from XGB's Recommended Price to Groundtruth (Gr) in 25,131 Repricing Events") 
sns.distplot(var2,ax=ax2,color='orange')
plt.figtext(1.0, 0.12, des2,fontsize=14)


plt.show()
# Out:
# (25131, 7)

# %%
df_res = pd.read_csv('reprice_Results_02.txt',low_memory=False)
print((df_res.shape))
df_res['RF-Gr'] = df_res['RandomForest'] - df_res['NextPrice']
df_res['XGB-Gr'] = df_res['XGBoost'] - df_res['NextPrice']


des1 = df_res['RF-Gr'].describe().reset_index()
des1.columns = ['', 'RF-Gr']
des1.reset_index(drop = True, inplace = True)

des2 = df_res['XGB-Gr'].describe().reset_index()
des2.columns = ['', 'XGB-Gr']
des2.reset_index(drop = True, inplace = True)

sns.set_style("whitegrid")
fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)
ax1.set_title("The Boxplot of Differences from RF's Recommended Prices to Groundtruth (Gr) in 9 Repricing Events") 
sns.boxplot(x=df_res['RF-Gr'],  color='lightblue',ax=ax1,orient='h')
plt.figtext(0.95, 0.55, des1,fontsize=14)

ax2.set_title("The Boxplot of Differences from XGB's Recommended Price to Groundtruth (Gr) in 9 Repricing Events") 
sns.boxplot(x=df_res['XGB-Gr'], color='orange',ax=ax2,orient='h')
plt.figtext(0.95, 0.15, des2,fontsize=14)



for i,artist in enumerate(ax2.artists):
    # Set the linecolor on the artist to the facecolor, and set the facecolor to None
    col = artist.get_facecolor()
    artist.set_edgecolor(col)
    artist.set_facecolor('None')

    # Each box has 6 associated Line2D objects (to make the whiskers, fliers, etc.)
    # Loop over them here, and use the same colour as above
    for j in range(i*6,i*6+6):
        line = ax2.lines[j]
        line.set_color(col)
        line.set_mfc(col)
        line.set_mec(col)


plt.show()
var1 = df_res['RF-Gr']
var2 = df_res['XGB-Gr']

fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)

ax1.set_title("The Histogram of Differences from RF's Recommended Prices to Groundtruth (Gr) in 9 Repricing Events") 
sns.distplot(var1,ax=ax1,color='blue')
plt.figtext(1.0, 0.55, des1,fontsize=14)

ax2.set_title("The Histogram of Differences from XGB's Recommended Price to Groundtruth (Gr) in 9 Repricing Events") 
sns.distplot(var2,ax=ax2,color='orange')
plt.figtext(1.0, 0.12, des2,fontsize=14)


plt.show()
# Out:
# (9, 7)

# %%
import seaborn as sns

df_res = pd.read_csv('reprice_Results_11.txt',low_memory=False)
print((df_res.shape))
df_res['RF-Gr'] = df_res['RandomForest'] - df_res['NextPrice']
df_res['XGB-Gr'] = df_res['XGBoost'] - df_res['NextPrice']


des1 = df_res['RF-Gr'].describe().reset_index()
des1.columns = ['', 'RF-Gr']
des1.reset_index(drop = True, inplace = True)

des2 = df_res['XGB-Gr'].describe().reset_index()
des2.columns = ['', 'XGB-Gr']
des2.reset_index(drop = True, inplace = True)

sns.set_style("whitegrid")
fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)
ax1.set_title("The Boxplot of Differences from RF's Recommended Prices to Groundtruth (Gr) in 24,989 Repricing Events") 
sns.boxplot(x=df_res['RF-Gr'],  color='lightblue',ax=ax1,orient='h')
plt.figtext(0.95, 0.55, des1,fontsize=14)

ax2.set_title("The Boxplot of Differences from XGB's Recommended Price to Groundtruth (Gr) in 24,989 Repricing Events") 
sns.boxplot(x=df_res['XGB-Gr'], color='orange',ax=ax2,orient='h')
plt.figtext(0.95, 0.15, des2,fontsize=14)



for i,artist in enumerate(ax2.artists):
    # Set the linecolor on the artist to the facecolor, and set the facecolor to None
    col = artist.get_facecolor()
    artist.set_edgecolor(col)
    artist.set_facecolor('None')

    # Each box has 6 associated Line2D objects (to make the whiskers, fliers, etc.)
    # Loop over them here, and use the same colour as above
    for j in range(i*6,i*6+6):
        line = ax2.lines[j]
        line.set_color(col)
        line.set_mfc(col)
        line.set_mec(col)


var1 = df_res['RF-Gr']
var2 = df_res['XGB-Gr']

fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)

ax1.set_title("The Histogram of Differences from RF's Recommended Prices to Groundtruth (Gr) in 24,989 Repricing Events") 
sns.distplot(var1,ax=ax1,color='blue')
plt.figtext(1.0, 0.55, des1,fontsize=14)

ax2.set_title("The Histogram of Differences from XGB's Recommended Price to Groundtruth (Gr) in 24,989 Repricing Events") 
sns.distplot(var2,ax=ax2,color='orange')
plt.figtext(1.0, 0.12, des2,fontsize=14)


plt.show()
# Out:
# (24989, 7)

# %%
import seaborn as sns

df_res = pd.read_csv('reprice_Results_12.txt',low_memory=False)
print((df_res.shape))
df_res['RF-Gr'] = df_res['RandomForest'] - df_res['NextPrice']
df_res['XGB-Gr'] = df_res['XGBoost'] - df_res['NextPrice']


des1 = df_res['RF-Gr'].describe().reset_index()
des1.columns = ['', 'RF-Gr']
des1.reset_index(drop = True, inplace = True)

des2 = df_res['XGB-Gr'].describe().reset_index()
des2.columns = ['', 'XGB-Gr']
des2.reset_index(drop = True, inplace = True)

sns.set_style("whitegrid")
fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)
ax1.set_title("The Boxplot of Differences from RF's Recommended Prices to Groundtruth (Gr) in 14 Repricing Events") 
sns.boxplot(x=df_res['RF-Gr'],  color='lightblue',ax=ax1,orient='h')
plt.figtext(0.95, 0.55, des1,fontsize=14)

ax2.set_title("The Boxplot of Differences from XGB's Recommended Price to Groundtruth (Gr) in 14 Repricing Events") 
sns.boxplot(x=df_res['XGB-Gr'], color='orange',ax=ax2,orient='h')
plt.figtext(0.95, 0.15, des2,fontsize=14)



for i,artist in enumerate(ax2.artists):
    # Set the linecolor on the artist to the facecolor, and set the facecolor to None
    col = artist.get_facecolor()
    artist.set_edgecolor(col)
    artist.set_facecolor('None')

    # Each box has 6 associated Line2D objects (to make the whiskers, fliers, etc.)
    # Loop over them here, and use the same colour as above
    for j in range(i*6,i*6+6):
        line = ax2.lines[j]
        line.set_color(col)
        line.set_mfc(col)
        line.set_mec(col)


var1 = df_res['RF-Gr']
var2 = df_res['XGB-Gr']

fig,(ax1,ax2) = plt.subplots(2)
fig.set_size_inches(15, 10)

ax1.set_title("The Histogram of Differences from RF's Recommended Prices to Groundtruth (Gr) in 14 Repricing Events") 
sns.distplot(var1,ax=ax1,color='blue')
plt.figtext(1.0, 0.55, des1,fontsize=14)

ax2.set_title("The Histogram of Differences from XGB's Recommended Price to Groundtruth (Gr) in 14 Repricing Events") 
sns.distplot(var2,ax=ax2,color='orange')
plt.figtext(1.0, 0.12, des2,fontsize=14)


plt.show()
# Out:
# (14, 7)
